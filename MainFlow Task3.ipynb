# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\householdtask3.csv")

# %%
df.describe()
# Out:
#               year       tot_hhs           own         own_wm   own_prop  \
# count    70.000000  7.000000e+01  7.000000e+01      70.000000  70.000000
# mean   2014.000000  4.125193e+05  2.689711e+05  129639.457143  63.505714
# std       4.273274  3.491547e+05  2.385230e+05  128627.124758  15.145257
# min    2008.000000  1.322150e+05  3.008000e+04   14220.000000  22.800000
# 25%    2011.000000  3.123460e+05  1.838408e+05   50636.750000  55.400000
# 50%    2014.000000  3.276340e+05  2.153065e+05  107909.000000  64.200000
# 75%    2017.000000  3.468958e+05  2.604148e+05  147563.000000  73.675000
# max    2020.000000  1.756740e+06  1.125000e+06  574662.000000  88.100000
#
#        own_wm_prop    prop_hhs        age       size         income  \
# count    70.000000   70.000000  70.000000  70.000000      70.000000
# mean     30.348571   24.985714  38.284286   2.625714   56694.785714
# std      14.010004   21.102368   9.376345   0.350439   28921.315551
# ...

# %%
df.columns
# Out:
# Index(['year', 'tot_hhs', 'own', 'own_wm', 'own_prop', 'own_wm_prop',
#        'prop_hhs', 'age', 'size', 'income', 'expenditure', 'eqv_income',
#        'eqv_exp'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# year           0
# tot_hhs        0
# own            0
# own_wm         0
# own_prop       0
# own_wm_prop    0
# prop_hhs       0
# age            0
# size           0
# income         0
# expenditure    0
# eqv_income     0
# eqv_exp        0
# dtype: int64

# %%
df.own.value_counts()
# Out:
# 1087580    1
# 182696     1
# 194770     1
# 181960     1
# 286886     1
#           ..
# 45834      1
# 171141     1
# 190496     1
# 219709     1
# 314154     1
# Name: own, Length: 70, dtype: int64

# %%
df.head()
# Out:
#    year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0  2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1  2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2  2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3  2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4  2008   312240   217657  141318      69.7         45.3      20.0  31.5
#
#    size  income  expenditure  eqv_income  eqv_exp
# 0   2.7   46704        42394       26869    25132
# 1   2.6   23404        25270       14258    15824
# 2   2.3   16747        21145       13402    14408
# 3   2.8   31308        29855       18917    18266
# 4   3.0   49106        46561       26870    24672

# %%
plt.plot(df.expenditure)
plt.xlabel("Number")
plt.ylabel("Expenditure")
# Out:
# Text(0, 0.5, 'Expenditure')

# %%
plt.style.use("seaborn")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11456\1490283864.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
plt.bar(x=df.year,height=df.expenditure)
plt.xlabel("Years")
plt.ylabel("Expenditure")
# Out:
# Text(0, 0.5, 'Expenditure')

# %%
plt.bar(x=df.year,height=df.expenditure)
plt.xlabel("Years")
plt.ylabel("Income")
plt.title("BAR Graph")
# Out:
# Text(0.5, 1.0, 'BAR Graph')

# %%
plt.plot(df.year,df.income)
plt.scatter(df.year,df.income)
plt.xlabel("Years")
plt.ylabel("Income")
plt.title("Line Graph")
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(df.year,df.prop_hhs)
plt.scatter(df.year,df.prop_hhs)
plt.xlabel("Years")
plt.ylabel("Prop_hhs")
plt.title("Line Graph")
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.subplot(2,2,1)
plt.boxplot(df.income)
plt.xlabel("Income")
plt.subplot(2,2,2)
plt.boxplot(df.expenditure)
plt.xlabel("Expenditure")
plt.subplot(2,2,3)
plt.boxplot(df.age)
plt.xlabel("Age")
plt.subplot(2,2,4)
plt.boxplot(df.eqv_income)
plt.xlabel("eqv_income")
# Out:
# Text(0.5, 0, 'eqv_income')

# %%
plt.boxplot(df.eqv_exp)
plt.xlabel("eqv_exp")
# Out:
# Text(0.5, 0, 'eqv_exp')

# %%
plt.violinplot(df.expenditure)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1dcd100ffd0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1dcd1024750>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1dcd1026050>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1dcd1027910>}
